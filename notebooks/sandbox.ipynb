# %%
# %%capture
# %load_ext autoreload
# %autoreload 2
# %load_ext dotenv
# %dotenv

import sys
from pathlib import Path

# Add the project root to Python path
project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(project_root))

# %%
from datetime import datetime
from src.domain import Event, EventStatus, EventLevel

# %%
from src.application.use_cases.real_time_even_processor import RealTimeEventProcessor, event_parser

# %%
event_parser(
    {
        "id": 1,
        "source": "sensor-temperature-01",
        "level": "CRITICAL",
        "timestamp": "2026-02-13T10:30:00",
        "status": "NEW",
        "should_alert": False,
        "metadata": {
            "temperature": 85.5,
            "unit": "celsius",
            "location": "server-room-A",
        },
    }
)
# Out:
# []

# %%
mem_leak = Event(
    id=1,
    source="apolo_c001",
    metadata={
        "cpu_usage": 0.8,
        "memory_usage": 0.5,
    },
    level=EventLevel.INFO,
    timestamp=datetime.now(),
    status=EventStatus.NEW,
)

# %%
mem_leak.id
# Out:
# 1

# %%
print(mem_leak.is_acknowledged())
print(mem_leak.is_resolved())
# Out:
# False
# False

# %%
mem_leak.acknowledge()
mem_leak.resolve()

# %%
from src.domain import IRule, IAlertService, IDisplayService, IEventRepository

# %%
class MemoryFastEventRepository(IEventRepository):
    def __init__(self):
        self.events_dict = {}

    def save(self, events: list[Event]) -> None:
        for event in events:
            self.events_dict[event.id] = event

    def get_event_by_id(self, id: int) -> Event:
        return self.events_dict[id]
    
    def get_all_events(self) -> list[Event]:
        return list(self.events_dict.values())

# %%
class DummyAlertService(IAlertService):
    def alert(self, events: list[Event]) -> None:
        print(f"Alerting {events}")

class DummyDisplayService(IDisplayService):
    def show(self, events: list[Event]) -> None:
        print(f"Displaying {events}")

# %%
from datetime import timedelta

class SimpleRule(IRule):
    def apply(self, events: list[Event]) -> Event | list[Event] | None:
        for event in events:
            if event.level in [EventLevel.ERROR, EventLevel.CRITICAL]:
                if event.timestamp < (datetime.now() - timedelta(minutes=10)):
                    event.set_as_alerting()
        return events

# %%
rules = SimpleRule()
repository = MemoryFastEventRepository()
alert_service = DummyAlertService()
display_service = DummyDisplayService()

# %%
from src.application.use_cases.real_time_even_processor import RealTimeEventProcessor

processor = RealTimeEventProcessor(
    event_repository=repository,
    rule=rules,
    alert_service=alert_service,
    display_service=display_service
)

# %%
processor.process([mem_leak])
# Out:
# Alerting []
# Displaying Event(id=1, source=apolo_c001, metadata={'cpu_usage': 0.8, 'memory_usage': 0.5}, level=EventLevel.INFO, timestamp=2026-02-27 22:48:03.185121, status=EventStatus.RESOLVED, ack_timestamp=2026-02-27 22:48:03.226992, resolved_timestamp=2026-02-27 22:48:03.227014)

# %% [markdown]
# ## Test Payloads via MQTT

# %%
import aiomqtt
import json

BROKER = "broker.hivemq.com"
PORT = 1883
TOPIC = "ops-beacon/events"

async def publish_payload(payload: dict):
    async with aiomqtt.Client(BROKER, PORT) as client:
        await client.publish(TOPIC, json.dumps(payload))
        print(f"Publicado {len(payload.get('events', []))} evento(s) en {TOPIC}")

# %% [markdown]
# ### 1. CRITICAL antiguo — debería alertar

# %%
payload_1 = {
    "events": [
        {
            "id": 100,
            "source": "database-primary",
            "level": "CRITICAL",
            "timestamp": "2026-02-27T08:00:00",
            "metadata": {
                "error": "connection pool exhausted",
                "active_connections": 500,
                "max_connections": 500,
            },
        }
    ]
}
await publish_payload(payload_1)

# %% [markdown]
# ### 2. ERROR antiguo — debería alertar

# %%
payload_2 = {
    "events": [
        {
            "id": 101,
            "source": "api-gateway",
            "level": "ERROR",
            "timestamp": "2026-02-27T09:00:00",
            "metadata": {
                "endpoint": "/api/v1/users",
                "http_status": 503,
                "error": "upstream timeout after 30s",
            },
        }
    ]
}
await publish_payload(payload_2)

# %% [markdown]
# ### 3. ERROR reciente — NO debería alertar

# %%
from datetime import datetime, timedelta

# Timestamp de hace 2 minutos para que NO dispare la regla de 10 min
recent_ts = (datetime.now() - timedelta(minutes=2)).isoformat()

payload_3 = {
    "events": [
        {
            "id": 102,
            "source": "auth-service",
            "level": "ERROR",
            "timestamp": recent_ts,
            "metadata": {
                "user_id": "usr_42",
                "action": "login",
                "error": "invalid credentials",
            },
        }
    ]
}
await publish_payload(payload_3)

# %% [markdown]
# ### 4. Baja severidad (INFO, WARNING, DEBUG) — nunca alertan

# %%
payload_4 = {
    "events": [
        {
            "id": 103,
            "source": "load-balancer",
            "level": "INFO",
            "timestamp": "2026-02-27T08:00:00",
            "metadata": {"message": "health check passed", "response_time_ms": 12},
        },
        {
            "id": 104,
            "source": "cache-redis",
            "level": "WARNING",
            "timestamp": "2026-02-27T08:00:00",
            "metadata": {"memory_usage_pct": 85, "message": "memory usage high"},
        },
        {
            "id": 105,
            "source": "scheduler",
            "level": "DEBUG",
            "timestamp": "2026-02-27T07:00:00",
            "metadata": {"job": "cleanup_temp_files", "status": "started"},
        },
    ]
}
await publish_payload(payload_4)

# %% [markdown]
# ### 5. Batch mixto — solo CRITICAL y ERROR antiguos alertan

# %%
payload_5 = {
    "events": [
        {
            "id": 110,
            "source": "database-replica",
            "level": "CRITICAL",
            "timestamp": "2026-02-27T07:30:00",
            "metadata": {"error": "replication lag 120s", "lag_seconds": 120},
        },
        {
            "id": 111,
            "source": "api-gateway",
            "level": "ERROR",
            "timestamp": "2026-02-27T07:45:00",
            "metadata": {"endpoint": "/api/orders", "error": "rate limit exceeded"},
        },
        {
            "id": 112,
            "source": "monitoring",
            "level": "INFO",
            "timestamp": "2026-02-27T07:50:00",
            "metadata": {"message": "CPU usage normalized to 45%"},
        },
        {
            "id": 113,
            "source": "auth-service",
            "level": "WARNING",
            "timestamp": "2026-02-27T07:55:00",
            "metadata": {"message": "JWT token near expiration", "user_count": 23},
        },
    ]
}
await publish_payload(payload_5)

# %% [markdown]
# ### 6. Caso mínimo válido — solo campos requeridos

# %%
payload_6 = {
    "events": [
        {
            "id": 120,
            "source": "heartbeat",
            "level": "INFO",
            "timestamp": datetime.now().isoformat(),
        }
    ]
}
await publish_payload(payload_6)

# %% [markdown]
# ### Procesar localmente (sin MQTT) para verificar

# %%
# Parsear y procesar cualquier payload localmente (sin enviar por MQTT)
events = event_parser(payload_5)
processor.process(events)
